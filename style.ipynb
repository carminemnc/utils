# %%
import matplotlib.pyplot as plt
import numpy as np
import mplcyberpunk
import pandas as pd
import seaborn as sns
plt.style.use('light-theme.mplstyle')
penguins = sns.load_dataset("penguins")

# %%
from matplotlib import font_manager
# font path
font_path = 'Adelle-Regular.ttf'
font_manager.fontManager.addfont(font_path) # adding it
# global settings for the font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = font_manager.FontProperties(fname=font_path).get_name()

# %% [markdown]
# # Classic plot styling

# %%
x = np.arange(10)

for i in range(10):
    plt.plot(x,i*x)
mplcyberpunk.make_lines_glow() # glow effect
# plt.suptitle('This is the suptitle')
plt.title('This is the plot title',x=0)

plt.show()

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

dt = 0.01
t = np.arange(0, 30, dt)
nse1 = np.random.randn(len(t))                 # white noise 1
nse2 = np.random.randn(len(t))                 # white noise 2

# Two signals with a coherent part at 10 Hz and a random part
s1 = np.sin(2 * np.pi * 10 * t) + nse1
s2 = np.sin(2 * np.pi * 10 * t) + nse2

fig, axs = plt.subplots(1, 2,figsize=(12,5))

plt.suptitle('This is the main title')
axs[0].plot(t, s1, t, s2)
axs[0].set_xlim(0, 2)
axs[0].set_xlabel('Time (s)')
axs[0].set_ylabel('s1 and s2')
axs[0].grid(False)
axs[0].set_title('First plot')


cxy, f = axs[1].cohere(s1, s2, 256, 1. / dt)
axs[1].set_title('Second plot')
axs[1].set_ylabel('Coherence')
axs[1].grid(False)

plt.show()

# %%
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
plt.title('Seaborn hist plot')
plt.show()

# %%
sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")
plt.show()

# %%
sns.kdeplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
plt.title('Seaborn density plot')
plt.show()

# %%
sns.violinplot(data=penguins,x='sex',y='bill_depth_mm',hue='species')
plt.title('Seaborn violinplot')
plt.show()

# %%
sns.boxplot(data=penguins,x='sex',y='bill_depth_mm',hue='species')
plt.title('Seaborn boxplot')
plt.show()

# %%
# heatmap
glue = sns.load_dataset("glue").pivot(index="Model", columns="Task", values="Score")
ax = sns.heatmap(glue,annot=True,fmt='.2f',cmap='crest')
ax.xaxis.tick_top()
ax.set(ylabel='',xlabel='')
plt.show()

# %%
sns.pairplot(data=penguins,hue='sex',kind='kde')
plt.show()

# %% [markdown]
# # MPL cyberpunk

# %%
_ex = pd.DataFrame()
x = np.arange(-11, 11, 0.001)
_ex['sinc(x)'] = np.sinc(x)
_ex['sinc(x)/2'] = np.sinc(x)/2
# df['sinc(x)+'] = np.sinc(x)+0.12
_ex.plot()
mplcyberpunk.add_glow_effects(gradient_fill=True)
